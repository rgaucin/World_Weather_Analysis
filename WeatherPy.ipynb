# %%
# import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %%
# import requests library
import requests
# import weather api key
from config import weather_api_key

# %%
# import datetime module from datetime library
from datetime import datetime

# %%
# create a set of random latitude and longitude combinations
size = 1500
lats = np.random.uniform(-90, 90, size=size)
lngs = np.random.uniform(-180, 180, size=size)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# create a list for holding cities
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
# initial url for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# list to hold weather data
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    # group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # create endpoint url with each city
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing record {record_count} of set {set_count} | {city}")
    
    # update record count
    record_count += 1
    
    # run an API request for each city
    try:
        # parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # convert date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")
        # append the city information into the city_data list
        city_data.append({"City" : city.title(),
                          "Lat" : city_lat,
                          "Lng" : city_lng,
                          "Max Temp" : city_max_temp,
                          "Humidity" : city_humidity,
                          "Cloudiness" : city_clouds,
                          "Wind Speed" : city_wind,
                          "Country" : city_country,
                          "Date" : city_date})
    # if an error occurs, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 1 | ushuaia
# Processing record 2 of set 1 | sinnamary
# Processing record 3 of set 1 | saint-philippe
# Processing record 4 of set 1 | hobart
# Processing record 5 of set 1 | georgetown
# Processing record 6 of set 1 | rocha
# Processing record 7 of set 1 | riyadh
# Processing record 8 of set 1 | rikitea
# Processing record 9 of set 1 | andenes
# Processing record 10 of set 1 | dumas
# Processing record 11 of set 1 | arraial do cabo
# Processing record 12 of set 1 | mar del plata
# Processing record 13 of set 1 | college
# Processing record 14 of set 1 | albany
# Processing record 15 of set 1 | hithadhoo
# Processing record 16 of set 1 | sitka
# Processing record 17 of set 1 | williams lake
# Processing record 18 of set 1 | taolanaro
# City not found. Skipping...
# Processing record 19 of set 1 | castro
# Processing record 20 of set 1 | kapaa
# Processing record 21 of set 1 | dikson
# Processing record 22 of set 1 | bluff
# Processing record 23 of set 1 | vardo
# Processing record 24 of set 1 | provideniya
# Processing record 25 of set 1 | kunming
# Processing record 26 of set 1 | sao jose da coroa grande
# Processing record 27 of set 1 | la paz
# Processing record 28 of set 1 | sayalgudi
# City not found. Skipping...
# Processing record 29 of set 1 | kaitangata
# Processing record 30 of set 1 | butaritari
# Processing record 31 of set 1 | tautira
# Processing record 32 of set 1 | fortuna
# Processing record 33 of set 1 | jamestown
# Processing record 34 of set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing record 35 of set 1 | port hedland
# Processing record 36 of set 1 | lasa
# Processing record 37 of set 1 | saskylakh
# Processing record 38 of set 1 | coihaique
# Processing record 39 of set 1 | nizhneyansk
# City not found. Skipping...
# Processing record 40 of set 1 | beloeil
# Processing record 41 of set 1 | atuona
# Processing record 42 of set 1 | mount isa
# Processing record 43 of set 1 | cape town
# Processing record 44 of set 1 | dwarka
# Processing record 45 of set 1 | upernavik
# Processing record 46 of set 1 | kavaratti
# Processing record 47 of set 1 | puerto princesa
# Processing record 48 of set 1 | ca mau
# Processing record 49 of set 1 | tuban
# Processing record 50 of set 1 | bengkulu
# Processing record 1 of set 2 | naliya
# Processing record 2 of set 2 | mataura
# Processing record 3 of set 2 | puerto ayora
# Processing record 4 of set 2 | ilulissat
# Processing record 5 of set 2 | vaini
# Processing record 6 of set 2 | punta arenas
# Processing record 7 of set 2 | quatre cocos
# Processing record 8 of set 2 | busselton
# Processing record 9 of set 2 | amahai
# Processing record 10 of set 2 | saint-ambroise
# Processing record 11 of set 2 | tambopata
# Processing record 12 of set 2 | kodiak
# Processing record 13 of set 2 | nemuro
# Processing record 14 of set 2 | ambon
# Processing record 15 of set 2 | hermanus
# Processing record 16 of set 2 | carnarvon
# Processing record 17 of set 2 | cabra
# Processing record 18 of set 2 | wainwright
# Processing record 19 of set 2 | mazatlan
# Processing record 20 of set 2 | sisimiut
# Processing record 21 of set 2 | hualmay
# Processing record 22 of set 2 | dunda
# Processing record 23 of set 2 | avarua
# Processing record 24 of set 2 | erenhot
# Processing record 25 of set 2 | chuy
# Processing record 26 of set 2 | bredasdorp
# Processing record 27 of set 2 | beloha
# Processing record 28 of set 2 | sao joao da barra
# Processing record 29 of set 2 | vagay
# Processing record 30 of set 2 | kaiserslautern
# Processing record 31 of set 2 | nizhnyaya poyma
# Processing record 32 of set 2 | saint george
# Processing record 33 of set 2 | khatanga
# Processing record 34 of set 2 | dori
# Processing record 35 of set 2 | victoria
# Processing record 36 of set 2 | independencia
# Processing record 37 of set 2 | hilo
# Processing record 38 of set 2 | shebalino
# Processing record 39 of set 2 | chulym
# Processing record 40 of set 2 | mahebourg
# Processing record 41 of set 2 | qaanaaq
# Processing record 42 of set 2 | luderitz
# Processing record 43 of set 2 | ponta do sol
# Processing record 44 of set 2 | ucluelet
# Processing record 45 of set 2 | olafsvik
# Processing record 46 of set 2 | caconda
# Processing record 47 of set 2 | along
# Processing record 48 of set 2 | poum
# Processing record 49 of set 2 | oranmore
# Processing record 50 of set 2 | grand river south east
# City not found. Skipping...
# Processing record 1 of set 3 | balimo
# City not found. Skipping...
# Processing record 2 of set 3 | sentyabrskiy
# City not found. Skipping...
# Processing record 3 of set 3 | akdepe
# Processing record 4 of set 3 | ravar
# Processing record 5 of set 3 | ribeira grande
# Processing record 6 of set 3 | thompson
# Processing record 7 of set 3 | fukue
# Processing record 8 of set 3 | iqaluit
# Processing record 9 of set 3 | tabiauea
# City not found. Skipping...
# Processing record 10 of set 3 | bambous virieux
# Processing record 11 of set 3 | port lincoln
# Processing record 12 of set 3 | aguas formosas
# Processing record 13 of set 3 | ara
# Processing record 14 of set 3 | pangody
# Processing record 15 of set 3 | new norfolk
# Processing record 16 of set 3 | barrow
# Processing record 17 of set 3 | aswan
# Processing record 18 of set 3 | nikolskoye
# Processing record 19 of set 3 | meaux
# Processing record 20 of set 3 | attawapiskat
# City not found. Skipping...
# Processing record 21 of set 3 | arriana
# Processing record 22 of set 3 | gurgan
# City not found. Skipping...
# Processing record 23 of set 3 | bethel
# Processing record 24 of set 3 | temaraia
# City not found. Skipping...
# Processing record 25 of set 3 | tuktoyaktuk
# Processing record 26 of set 3 | verkhnevilyuysk
# Processing record 27 of set 3 | camacha
# Processing record 28 of set 3 | moron
# Processing record 29 of set 3 | komsomolskiy
# Processing record 30 of set 3 | gat
# Processing record 31 of set 3 | viking
# Processing record 32 of set 3 | vaitupu
# City not found. Skipping...
# Processing record 33 of set 3 | lebu
# Processing record 34 of set 3 | esperance
# Processing record 35 of set 3 | tasiilaq
# Processing record 36 of set 3 | warqla
# City not found. Skipping...
# Processing record 37 of set 3 | kauhajoki
# Processing record 38 of set 3 | nianzishan
# Processing record 39 of set 3 | adrar
# Processing record 40 of set 3 | amderma
# City not found. Skipping...
# Processing record 41 of set 3 | toamasina
# Processing record 42 of set 3 | lerwick
# Processing record 43 of set 3 | manzhouli
# Processing record 44 of set 3 | santa rosa
# Processing record 45 of set 3 | cranbrook
# Processing record 46 of set 3 | sistranda
# Processing record 47 of set 3 | aras
# Processing record 48 of set 3 | karatsu
# Processing record 49 of set 3 | kruisfontein
# Processing record 50 of set 3 | tazovskiy
# Processing record 1 of set 4 | tenkodogo
# Processing record 2 of set 4 | vitoria
# Processing record 3 of set 4 | lakes entrance
# Processing record 4 of set 4 | nhulunbuy
# Processing record 5 of set 4 | itaituba
# Processing record 6 of set 4 | batticaloa
# Processing record 7 of set 4 | bulancak
# Processing record 8 of set 4 | wanning
# Processing record 9 of set 4 | salalah
# Processing record 10 of set 4 | teya
# Processing record 11 of set 4 | sitrah
# Processing record 12 of set 4 | constitucion
# Processing record 13 of set 4 | mujiayingzi
# Processing record 14 of set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing record 15 of set 4 | fort saint john
# City not found. Skipping...
# Processing record 16 of set 4 | ancud
# Processing record 17 of set 4 | el alto
# Processing record 18 of set 4 | paamiut
# Processing record 19 of set 4 | korcula
# Processing record 20 of set 4 | las vegas
# Processing record 21 of set 4 | alcaniz
# Processing record 22 of set 4 | lavrentiya
# Processing record 23 of set 4 | tabou
# Processing record 24 of set 4 | ahipara
# Processing record 25 of set 4 | sorong
# Processing record 26 of set 4 | bonthe
# Processing record 27 of set 4 | pisco
# Processing record 28 of set 4 | chokurdakh
# Processing record 29 of set 4 | cidreira
# Processing record 30 of set 4 | vila velha
# Processing record 31 of set 4 | itoman
# Processing record 32 of set 4 | ugoofaaru
# Processing record 33 of set 4 | tahta
# Processing record 34 of set 4 | nuuk
# Processing record 35 of set 4 | inirida
# Processing record 36 of set 4 | bilky
# Processing record 37 of set 4 | bairiki
# Processing record 38 of set 4 | kashi
# Processing record 39 of set 4 | seoul
# Processing record 40 of set 4 | kahului
# Processing record 41 of set 4 | longyearbyen
# Processing record 42 of set 4 | benicarlo
# Processing record 43 of set 4 | yellowknife
# Processing record 44 of set 4 | mogadishu
# Processing record 45 of set 4 | nanortalik
# Processing record 46 of set 4 | octeville
# Processing record 47 of set 4 | santa maria do suacui
# Processing record 48 of set 4 | talcahuano
# Processing record 49 of set 4 | byron bay
# Processing record 50 of set 4 | saint-augustin
# Processing record 1 of set 5 | ubala
# Processing record 2 of set 5 | sofiysk
# City not found. Skipping...
# Processing record 3 of set 5 | souillac
# Processing record 4 of set 5 | hasaki
# Processing record 5 of set 5 | labuhan
# Processing record 6 of set 5 | katsiveli
# City not found. Skipping...
# Processing record 7 of set 5 | guerrero negro
# Processing record 8 of set 5 | cockburn town
# Processing record 9 of set 5 | hofn
# Processing record 10 of set 5 | rungata
# City not found. Skipping...
# Processing record 11 of set 5 | sven
# Processing record 12 of set 5 | namibe
# Processing record 13 of set 5 | svetlaya
# Processing record 14 of set 5 | tiksi
# Processing record 15 of set 5 | payakumbuh
# Processing record 16 of set 5 | ngukurr
# City not found. Skipping...
# Processing record 17 of set 5 | udachnyy
# Processing record 18 of set 5 | necochea
# Processing record 19 of set 5 | eyl
# Processing record 20 of set 5 | tornio
# Processing record 21 of set 5 | abu samrah
# Processing record 22 of set 5 | norman wells
# Processing record 23 of set 5 | ruatoria
# City not found. Skipping...
# Processing record 24 of set 5 | kamenka
# Processing record 25 of set 5 | tekkalakota
# City not found. Skipping...
# Processing record 26 of set 5 | goryachegorsk
# Processing record 27 of set 5 | tiznit
# Processing record 28 of set 5 | egvekinot
# Processing record 29 of set 5 | kapoeta
# Processing record 30 of set 5 | rajakhera
# Processing record 31 of set 5 | klaksvik
# Processing record 32 of set 5 | kodinsk
# Processing record 33 of set 5 | lundazi
# Processing record 34 of set 5 | leningradskiy
# Processing record 35 of set 5 | tonantins
# Processing record 36 of set 5 | leshukonskoye
# Processing record 37 of set 5 | sosnovo-ozerskoye
# Processing record 38 of set 5 | la ronge
# Processing record 39 of set 5 | kharp
# Processing record 40 of set 5 | jackson
# Processing record 41 of set 5 | biak
# Processing record 42 of set 5 | san matias
# Processing record 43 of set 5 | krasnomayskiy
# Processing record 44 of set 5 | veraval
# Processing record 45 of set 5 | morro bay
# Processing record 46 of set 5 | kardzhin
# Processing record 47 of set 5 | saint-georges
# Processing record 48 of set 5 | adolfo lopez mateos
# Processing record 49 of set 5 | east london
# Processing record 50 of set 5 | turukhansk
# Processing record 1 of set 6 | upata
# Processing record 2 of set 6 | hambantota
# Processing record 3 of set 6 | mount gambier
# Processing record 4 of set 6 | barentsburg
# City not found. Skipping...
# Processing record 5 of set 6 | jacareacanga
# Processing record 6 of set 6 | port elizabeth
# Processing record 7 of set 6 | khandyga
# Processing record 8 of set 6 | belushya guba
# City not found. Skipping...
# Processing record 9 of set 6 | esso
# Processing record 10 of set 6 | clyde river
# Processing record 11 of set 6 | maragogi
# Processing record 12 of set 6 | goya
# Processing record 13 of set 6 | derzhavinsk
# Processing record 14 of set 6 | calvinia
# Processing record 15 of set 6 | vestmanna
# Processing record 16 of set 6 | te anau
# Processing record 17 of set 6 | saleaula
# City not found. Skipping...
# Processing record 18 of set 6 | sola
# Processing record 19 of set 6 | avera
# Processing record 20 of set 6 | yumen
# Processing record 21 of set 6 | flin flon
# Processing record 22 of set 6 | katsuura
# Processing record 23 of set 6 | geraldton
# Processing record 24 of set 6 | ulladulla
# Processing record 25 of set 6 | hihifo
# City not found. Skipping...
# Processing record 26 of set 6 | roald
# Processing record 27 of set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing record 28 of set 6 | pevek
# Processing record 29 of set 6 | kavieng
# Processing record 30 of set 6 | sao filipe
# Processing record 31 of set 6 | tabuk
# Processing record 32 of set 6 | nara
# Processing record 33 of set 6 | nevel
# Processing record 34 of set 6 | awjilah
# Processing record 35 of set 6 | bratsk
# Processing record 36 of set 6 | columbus
# Processing record 37 of set 6 | tuatapere
# Processing record 38 of set 6 | dalmatovo
# Processing record 39 of set 6 | umzimvubu
# City not found. Skipping...
# Processing record 40 of set 6 | kangaatsiaq
# Processing record 41 of set 6 | cayenne
# Processing record 42 of set 6 | cabo san lucas
# Processing record 43 of set 6 | henties bay
# Processing record 44 of set 6 | nguru
# Processing record 45 of set 6 | ambulu
# Processing record 46 of set 6 | keffi
# Processing record 47 of set 6 | oranjemund
# Processing record 48 of set 6 | keroka
# Processing record 49 of set 6 | tilichiki
# Processing record 50 of set 6 | hay river
# Processing record 1 of set 7 | susanville
# Processing record 2 of set 7 | inverell
# Processing record 3 of set 7 | wewak
# Processing record 4 of set 7 | port alfred
# Processing record 5 of set 7 | yazykovo
# Processing record 6 of set 7 | nador
# Processing record 7 of set 7 | cascais
# Processing record 8 of set 7 | celestun
# Processing record 9 of set 7 | nishihara
# Processing record 10 of set 7 | xining
# Processing record 11 of set 7 | khovu-aksy
# Processing record 12 of set 7 | sambava
# Processing record 13 of set 7 | springbok
# Processing record 14 of set 7 | norrtalje
# Processing record 15 of set 7 | challapata
# Processing record 16 of set 7 | assomada
# Processing record 17 of set 7 | alofi
# Processing record 18 of set 7 | russell
# Processing record 19 of set 7 | bonavista
# Processing record 20 of set 7 | brainerd
# Processing record 21 of set 7 | luxeuil-les-bains
# Processing record 22 of set 7 | sangar
# Processing record 23 of set 7 | seydi
# Processing record 24 of set 7 | eskasem
# City not found. Skipping...
# Processing record 25 of set 7 | santa cruz
# Processing record 26 of set 7 | tsihombe
# City not found. Skipping...
# Processing record 27 of set 7 | huarmey
# Processing record 28 of set 7 | haibowan
# City not found. Skipping...
# Processing record 29 of set 7 | saryozek
# Processing record 30 of set 7 | lensk
# Processing record 31 of set 7 | babanusah
# City not found. Skipping...
# Processing record 32 of set 7 | saldanha
# Processing record 33 of set 7 | hovd
# Processing record 34 of set 7 | shenkursk
# Processing record 35 of set 7 | khani
# Processing record 36 of set 7 | auki
# Processing record 37 of set 7 | portland
# Processing record 38 of set 7 | tongchuan
# Processing record 39 of set 7 | codrington
# Processing record 40 of set 7 | jalu
# Processing record 41 of set 7 | lugo
# Processing record 42 of set 7 | tumannyy
# City not found. Skipping...
# Processing record 43 of set 7 | vestmannaeyjar
# Processing record 44 of set 7 | nelson bay
# Processing record 45 of set 7 | vasto
# Processing record 46 of set 7 | hope
# Processing record 47 of set 7 | yaan
# Processing record 48 of set 7 | javanrud
# Processing record 49 of set 7 | krasnoselkup
# Processing record 50 of set 7 | utiroa
# City not found. Skipping...
# Processing record 1 of set 8 | iraquara
# Processing record 2 of set 8 | mitsamiouli
# Processing record 3 of set 8 | solnechnyy
# Processing record 4 of set 8 | okhotsk
# Processing record 5 of set 8 | alice springs
# Processing record 6 of set 8 | brae
# Processing record 7 of set 8 | juneau
# Processing record 8 of set 8 | shuangyang
# Processing record 9 of set 8 | vanimo
# Processing record 10 of set 8 | havoysund
# Processing record 11 of set 8 | moba
# Processing record 12 of set 8 | muzhi
# Processing record 13 of set 8 | cozumel
# Processing record 14 of set 8 | lodja
# Processing record 15 of set 8 | laguna
# Processing record 16 of set 8 | sumbawa
# City not found. Skipping...
# Processing record 17 of set 8 | galesong
# Processing record 18 of set 8 | izumo
# Processing record 19 of set 8 | alotau
# City not found. Skipping...
# Processing record 20 of set 8 | safwah
# City not found. Skipping...
# Processing record 21 of set 8 | lakshettipet
# Processing record 22 of set 8 | xinmin
# Processing record 23 of set 8 | hutchinson
# Processing record 24 of set 8 | canutama
# Processing record 25 of set 8 | handwara
# City not found. Skipping...
# Processing record 26 of set 8 | cairns
# Processing record 27 of set 8 | aflu
# City not found. Skipping...
# Processing record 28 of set 8 | sault sainte marie
# Processing record 29 of set 8 | santa isabel do rio negro
# Processing record 30 of set 8 | bull savanna
# Processing record 31 of set 8 | strezhevoy
# Processing record 32 of set 8 | montefiascone
# Processing record 33 of set 8 | port-gentil
# Processing record 34 of set 8 | porto empedocle
# Processing record 35 of set 8 | trelew
# Processing record 36 of set 8 | zaruma
# Processing record 37 of set 8 | anamur
# Processing record 38 of set 8 | bonnyville
# Processing record 39 of set 8 | maumere
# Processing record 40 of set 8 | negara
# Processing record 41 of set 8 | rio gallegos
# Processing record 42 of set 8 | ishigaki
# Processing record 43 of set 8 | caravelas
# Processing record 44 of set 8 | mastic beach
# Processing record 45 of set 8 | asau
# Processing record 46 of set 8 | altay
# Processing record 47 of set 8 | beyneu
# Processing record 48 of set 8 | millerovo
# Processing record 49 of set 8 | sur
# Processing record 50 of set 8 | placerville
# Processing record 1 of set 9 | sept-iles
# Processing record 2 of set 9 | kattivakkam
# Processing record 3 of set 9 | sobolevo
# Processing record 4 of set 9 | nogliki
# Processing record 5 of set 9 | fernley
# Processing record 6 of set 9 | mys shmidta
# City not found. Skipping...
# Processing record 7 of set 9 | nortelandia
# Processing record 8 of set 9 | samusu
# City not found. Skipping...
# Processing record 9 of set 9 | lompoc
# Processing record 10 of set 9 | berdigestyakh
# Processing record 11 of set 9 | mutsamudu
# City not found. Skipping...
# Processing record 12 of set 9 | yulara
# Processing record 13 of set 9 | taoudenni
# Processing record 14 of set 9 | abidjan
# Processing record 15 of set 9 | narsaq
# Processing record 16 of set 9 | maningrida
# Processing record 17 of set 9 | najran
# Processing record 18 of set 9 | bilma
# Processing record 19 of set 9 | padang
# Processing record 20 of set 9 | ohara
# Processing record 21 of set 9 | vila franca do campo
# Processing record 22 of set 9 | san patricio
# Processing record 23 of set 9 | luanda
# Processing record 24 of set 9 | play cu
# City not found. Skipping...
# Processing record 25 of set 9 | kloulklubed
# Processing record 26 of set 9 | dingle
# Processing record 27 of set 9 | lysyanka
# Processing record 28 of set 9 | taltal
# Processing record 29 of set 9 | richards bay
# Processing record 30 of set 9 | taywarah
# Processing record 31 of set 9 | myre
# Processing record 32 of set 9 | salinopolis
# Processing record 33 of set 9 | aljezur
# Processing record 34 of set 9 | watsa
# Processing record 35 of set 9 | denpasar
# Processing record 36 of set 9 | port hardy
# Processing record 37 of set 9 | chicama
# Processing record 38 of set 9 | abakaliki
# Processing record 39 of set 9 | kaura namoda
# Processing record 40 of set 9 | rongcheng
# Processing record 41 of set 9 | pemangkat
# Processing record 42 of set 9 | phan rang
# City not found. Skipping...
# Processing record 43 of set 9 | pangoa
# Processing record 44 of set 9 | cotonou
# Processing record 45 of set 9 | sao lourenco do sul
# Processing record 46 of set 9 | kudahuvadhoo
# Processing record 47 of set 9 | bathsheba
# Processing record 48 of set 9 | wahiawa
# Processing record 49 of set 9 | mao
# Processing record 50 of set 9 | road town
# Processing record 1 of set 10 | okha
# Processing record 2 of set 10 | airai
# Processing record 3 of set 10 | villarrica
# Processing record 4 of set 10 | vostok
# Processing record 5 of set 10 | faanui
# Processing record 6 of set 10 | palabuhanratu
# City not found. Skipping...
# Processing record 7 of set 10 | torbay
# Processing record 8 of set 10 | rawson
# Processing record 9 of set 10 | atambua
# Processing record 10 of set 10 | talnakh
# Processing record 11 of set 10 | bouna
# Processing record 12 of set 10 | nabire
# Processing record 13 of set 10 | benguela
# Processing record 14 of set 10 | wuda
# Processing record 15 of set 10 | iquitos
# Processing record 16 of set 10 | shizunai
# Processing record 17 of set 10 | majene
# Processing record 18 of set 10 | chaohu
# Processing record 19 of set 10 | kendari
# Processing record 20 of set 10 | alekseyevskoye
# Processing record 21 of set 10 | sukpak
# Processing record 22 of set 10 | shurob
# Processing record 23 of set 10 | whyalla
# Processing record 24 of set 10 | hamilton
# Processing record 25 of set 10 | guiyang
# Processing record 26 of set 10 | lapeer
# Processing record 27 of set 10 | srednekolymsk
# Processing record 28 of set 10 | matamoros
# Processing record 29 of set 10 | dongobesh
# Processing record 30 of set 10 | fomboni
# Processing record 31 of set 10 | tygda
# Processing record 32 of set 10 | shimoda
# Processing record 33 of set 10 | bradu
# Processing record 34 of set 10 | mehamn
# Processing record 35 of set 10 | yakeshi
# Processing record 36 of set 10 | pacific grove
# Processing record 37 of set 10 | almaznyy
# Processing record 38 of set 10 | sorvag
# City not found. Skipping...
# Processing record 39 of set 10 | ixtapa
# Processing record 40 of set 10 | kununurra
# Processing record 41 of set 10 | batagay-alyta
# Processing record 42 of set 10 | teknaf
# Processing record 43 of set 10 | san carlos de bariloche
# Processing record 44 of set 10 | fenoarivo
# Processing record 45 of set 10 | la romana
# Processing record 46 of set 10 | lorengau
# Processing record 47 of set 10 | severo-kurilsk
# Processing record 48 of set 10 | komarovo
# Processing record 49 of set 10 | marcona
# City not found. Skipping...
# Processing record 50 of set 10 | araouane
# Processing record 1 of set 11 | mitu
# Processing record 2 of set 11 | guerrero
# Processing record 3 of set 11 | deputatskiy
# Processing record 4 of set 11 | prince rupert
# Processing record 5 of set 11 | casa nova
# Processing record 6 of set 11 | erdenet
# Processing record 7 of set 11 | ushibuka
# Processing record 8 of set 11 | bafoulabe
# Processing record 9 of set 11 | blagoyevo
# Processing record 10 of set 11 | grand-bourg
# Processing record 11 of set 11 | monrovia
# Processing record 12 of set 11 | umba
# Processing record 13 of set 11 | dieppe
# Processing record 14 of set 11 | pasighat
# Processing record 15 of set 11 | savalou
# Processing record 16 of set 11 | komatipoort
# Processing record 17 of set 11 | san jose
# Processing record 18 of set 11 | mazamari
# Processing record 19 of set 11 | dubbo
# Processing record 20 of set 11 | chagda
# City not found. Skipping...
# Processing record 21 of set 11 | cherskiy
# Processing record 22 of set 11 | touros
# Processing record 23 of set 11 | isangel
# Processing record 24 of set 11 | dabat
# Processing record 25 of set 11 | barra
# Processing record 26 of set 11 | ponta delgada
# Processing record 27 of set 11 | orlik
# Processing record 28 of set 11 | burica
# City not found. Skipping...
# Processing record 29 of set 11 | karratha
# Processing record 30 of set 11 | kota kinabalu
# Processing record 31 of set 11 | kropotkin
# Processing record 32 of set 11 | gualaquiza
# Processing record 33 of set 11 | karpenision
# City not found. Skipping...
# Processing record 34 of set 11 | frejus
# Processing record 35 of set 11 | angangxi
# City not found. Skipping...
# Processing record 36 of set 11 | kismayo
# Processing record 37 of set 11 | sinjar
# Processing record 38 of set 11 | dobre miasto
# Processing record 39 of set 11 | nome
# Processing record 40 of set 11 | saint-joseph
# Processing record 41 of set 11 | lingao
# Processing record 42 of set 11 | unity
# Processing record 43 of set 11 | morondava
# Processing record 44 of set 11 | tessalit
# Processing record 45 of set 11 | vanavara
# Processing record 46 of set 11 | voka
# Processing record 47 of set 11 | panotla
# Processing record 48 of set 11 | wasilla
# Processing record 49 of set 11 | tubruq
# City not found. Skipping...
# Processing record 50 of set 11 | parksville
# Processing record 1 of set 12 | westport
# Processing record 2 of set 12 | saravan
# Processing record 3 of set 12 | palana
# Processing record 4 of set 12 | chichimila
# Processing record 5 of set 12 | qurayyat
# Processing record 6 of set 12 | areosa
# Processing record 7 of set 12 | faya
# Processing record 8 of set 12 | chapais
# Processing record 9 of set 12 | moranbah
# Processing record 10 of set 12 | mkushi
# Processing record 11 of set 12 | mana
# Processing record 12 of set 12 | pasni
# Processing record 13 of set 12 | lagoa
# Processing record 14 of set 12 | santiago del estero
# Processing record 15 of set 12 | laukaa
# Processing record 16 of set 12 | florianopolis
# Processing record 17 of set 12 | kulhudhuffushi
# Processing record 18 of set 12 | san cristobal
# Processing record 19 of set 12 | bambanglipuro
# Processing record 20 of set 12 | la palma
# Processing record 21 of set 12 | batagay
# Processing record 22 of set 12 | coruripe
# Processing record 23 of set 12 | araguacu
# Processing record 24 of set 12 | malakal
# Processing record 25 of set 12 | kutum
# Processing record 26 of set 12 | locri
# Processing record 27 of set 12 | mattru
# Processing record 28 of set 12 | saint anthony
# Processing record 29 of set 12 | yenagoa
# Processing record 30 of set 12 | omsukchan
# Processing record 31 of set 12 | lata
# Processing record 32 of set 12 | zabaykalsk
# Processing record 33 of set 12 | meulaboh
# Processing record 34 of set 12 | floro
# Processing record 35 of set 12 | rajpipla
# Processing record 36 of set 12 | sehithwa
# Processing record 37 of set 12 | toronto
# Processing record 38 of set 12 | tigzirt
# Processing record 39 of set 12 | bur gabo
# City not found. Skipping...
# Processing record 40 of set 12 | himora
# City not found. Skipping...
# Processing record 41 of set 12 | itarema
# Processing record 42 of set 12 | saint stephen
# Processing record 43 of set 12 | cururupu
# Processing record 44 of set 12 | pemex
# Processing record 45 of set 12 | nalut
# Processing record 46 of set 12 | igra
# Processing record 47 of set 12 | niquelandia
# Processing record 48 of set 12 | namikupa
# Processing record 49 of set 12 | ejura
# Processing record 50 of set 12 | grindavik
# Processing record 1 of set 13 | la paz centro
# Processing record 2 of set 13 | karaman
# Processing record 3 of set 13 | warrington
# Processing record 4 of set 13 | oxford
# Processing record 5 of set 13 | viedma
# Processing record 6 of set 13 | macaboboni
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check the number of cities added to the list
len(city_data)
# Out:
# 551

# %%
# convert the array of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia -54.8000  -68.3000     44.26        76          40
# 1       Sinnamary   5.3833  -52.9500     82.15        78          13
# 2  Saint-Philippe -21.3585   55.7679     67.55        75          43
# 3          Hobart -42.8794  147.3294     51.26        69          75
# 4      Georgetown   5.4112  100.3354     84.13        77          20
# 5           Rocha -34.4833  -54.3333     51.51        76          83
# 6          Riyadh  24.6877   46.7219     98.64        27          99
# 7         Rikitea -23.1203 -134.9692     73.49        72          15
# 8         Andenes  69.3143   16.1194     48.07        93          90
# 9           Dumas  35.8656 -101.9732     90.82        29           1
#
#    Wind Speed Country                 Date
# 0       10.36      AR  2021-07-22 20:58:08
# 1       11.39      GF  2021-07-22 21:02:58
# 2       12.08      RE  2021-07-22 21:02:59
# 3        1.99      AU  2021-07-22 21:02:59
# 4        8.05      MY  2021-07-22 21:03:00
# 5        6.08      UY  2021-07-22 21:01:09
# 6        5.03      SA  2021-07-22 21:03:01
# 7       18.12      PF  2021-07-22 21:03:01
# 8       17.27      NO  2021-07-22 21:02:11
# 9       18.41      US  2021-07-22 21:03:02

# %%
# reorder the DataFrame columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Ushuaia      AR  2021-07-22 20:58:08 -54.8000  -68.3000     44.26
# 1       Sinnamary      GF  2021-07-22 21:02:58   5.3833  -52.9500     82.15
# 2  Saint-Philippe      RE  2021-07-22 21:02:59 -21.3585   55.7679     67.55
# 3          Hobart      AU  2021-07-22 21:02:59 -42.8794  147.3294     51.26
# 4      Georgetown      MY  2021-07-22 21:03:00   5.4112  100.3354     84.13
# 5           Rocha      UY  2021-07-22 21:01:09 -34.4833  -54.3333     51.51
# 6          Riyadh      SA  2021-07-22 21:03:01  24.6877   46.7219     98.64
# 7         Rikitea      PF  2021-07-22 21:03:01 -23.1203 -134.9692     73.49
# 8         Andenes      NO  2021-07-22 21:02:11  69.3143   16.1194     48.07
# 9           Dumas      US  2021-07-22 21:03:02  35.8656 -101.9732     90.82
#
#    Humidity  Cloudiness  Wind Speed
# 0        76          40       10.36
# 1        78          13       11.39
# 2        75          43       12.08
# 3        69          75        1.99
# 4        77          20        8.05
# 5        76          83        6.08
# 6        27          99        5.03
# 7        72          15       18.12
# 8        93          90       17.27
# 9        29           1       18.41

# %%
# create output file
output_file = "weather_data/cities.csv"
# export city_data to csv
city_data_df.to_csv(output_file, index_label="City ID")

# %%
# extract relevant fields from DataFrame for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# import time modules
import time

# function to build scatter plot for data
def build_scatter(title, unit, data_field, plot_num):

    # build scatter plot for lats vs data field
    plt.scatter(lats,
            data_field,
            edgecolor="black", linewidth=1, marker="o",
            alpha=0.8, label="Cities")

    # incorporate other graph properties
    plt.title("City Latitude vs. " + title + " " + time.strftime("%x"))
    plt.ylabel(f"{title} ({unit})")
    plt.xlabel("Latitude")
    plt.grid(True)

    # save the figure
    plt.savefig("weather_data/Fig" + str(plot_num) + ".png")

    # show plot
    plt.show()

# assemble data fields and associated info into dictionary
data_field_dict = {"Max Temperature" : [max_temps, "F"],
                   "Humidity" : [humidity, "%"],
                   "Cloudiness" : [cloudiness, "%"],
                   "Wind Speed" : [wind_speed, "%"]}

# build scatter plot for each data field vs city latitude
for i, (data_title, field_info) in enumerate(data_field_dict.items()):
    build_scatter(data_title, field_info[1], field_info[0], i)
