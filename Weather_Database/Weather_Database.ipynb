# %%
# import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from citipy import citipy

import requests

from config import weather_api_key

# %%
# generate random latitudes and longitudes
coord_size = 2000
lats = np.random.uniform(-90, 90, size=coord_size)
lngs = np.random.uniform(-180, 180, size=coord_size)
coordinates = list(zip(lats, lngs))

# %%
# create a list for holding cities
cities = []
for coord in coordinates:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
city_data = []

# set parameters for API call
params = {"units": "imperial",
          "appid": weather_api_key}

# initial url for Weather Map API call
base_url = "http://api.openweathermap.org/data/2.5/weather"

record_count = 1
set_count = 1

# indicate beginning of data retrieval
print("-----------------------------")
print("Beginning Data Retrieval")
print("-----------------------------")

for i, city in enumerate(cities):
    # group cities in sets of 50 for logging purposes
    if((i % 50 == 0) and (i >= 50)):
        record_count = 1
        set_count += 1
    
    # log current request
    print(f"Processing record {record_count} of set {set_count} | {city}")
    
    # create endpoint url with each city
    params["q"] = city.replace(" ", "+")
    
    # update record count
    record_count += 1
    
    # make API request and add info to data list
    try:
        city_weather = requests.get(base_url, params=params).json()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloud = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather["weather"][0]["description"]
        city_data.append({"City" : city.title(),
                          "Country" : city_country,
                          "Lat" : city_lat,
                          "Lng" : city_lng,
                          "Max Temp" : city_max_temp,
                          "Humidity" : city_humidity,
                          "Cloudiness" : city_cloud,
                          "Wind Speed" : city_wind,
                          "Current Description" : city_descrip})
    # if city not found, skip
    except:
        print(f"City: {city} not found. Skipping...")
        pass
        
# indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 1 | hohr-grenzhausen
# Processing record 2 of set 1 | punta arenas
# City: punta arenas not found. Skipping...
# Processing record 3 of set 1 | narsaq
# Processing record 4 of set 1 | mahebourg
# Processing record 5 of set 1 | hithadhoo
# Processing record 6 of set 1 | hilo
# Processing record 7 of set 1 | rikitea
# Processing record 8 of set 1 | trairi
# Processing record 9 of set 1 | broome
# Processing record 10 of set 1 | butaritari
# Processing record 11 of set 1 | provideniya
# Processing record 12 of set 1 | tuktoyaktuk
# Processing record 13 of set 1 | thompson
# Processing record 14 of set 1 | faanui
# Processing record 15 of set 1 | vaini
# Processing record 16 of set 1 | taolanaro
# City: taolanaro not found. Skipping...
# Processing record 17 of set 1 | albany
# Processing record 18 of set 1 | kapaa
# Processing record 19 of set 1 | illoqqortoormiut
# City: illoqqortoormiut not found. Skipping...
# Processing record 20 of set 1 | belushya guba
# City: belushya guba not found. Skipping...
# Processing record 21 of set 1 | barentsburg
# City: barentsburg not found. Skipping...
# Processing record 22 of set 1 | ushuaia
# Processing record 23 of set 1 | sitka
# Processing record 24 of set 1 | qaanaaq
# Processing record 25 of set 1 | patan
# Processing record 26 of set 1 | saint-philippe
# Processing record 27 of set 1 | victoria
# Processing record 28 of set 1 | luwuk
# Processing record 29 of set 1 | sulangan
# Processing record 30 of set 1 | kurumkan
# Processing record 31 of set 1 | el dorado
# City: el dorado not found. Skipping...
# Processing record 32 of set 1 | codrington
# Processing record 33 of set 1 | margate
# Processing record 34 of set 1 | washington
# Processing record 35 of set 1 | bredasdorp
# Processing record 36 of set 1 | vuktyl
# Processing record 37 of set 1 | pisco
# Processing record 38 of set 1 | taungdwingyi
# Processing record 39 of set 1 | rosamorada
# Processing record 40 of set 1 | avarua
# Processing record 41 of set 1 | pangnirtung
# Processing record 42 of set 1 | bluff
# Processing record 43 of set 1 | port alfred
# City: port alfred not found. Skipping...
# Processing record 44 of set 1 | ayan
# Processing record 45 of set 1 | george town
# City: george town not found. Skipping...
# Processing record 46 of set 1 | hongjiang
# Processing record 47 of set 1 | los llanos de aridane
# City: los llanos de aridane not found. Skipping...
# Processing record 48 of set 1 | jackson
# Processing record 49 of set 1 | khatanga
# Processing record 50 of set 1 | mataura
# Processing record 1 of set 2 | marzuq
# Processing record 2 of set 2 | mar del plata
# City: mar del plata not found. Skipping...
# Processing record 3 of set 2 | mitchell
# Processing record 4 of set 2 | tabuk
# Processing record 5 of set 2 | kapit
# Processing record 6 of set 2 | wladyslawowo
# Processing record 7 of set 2 | mpulungu
# Processing record 8 of set 2 | teya
# Processing record 9 of set 2 | castro
# Processing record 10 of set 2 | hobart
# Processing record 11 of set 2 | san luis
# City: san luis not found. Skipping...
# Processing record 12 of set 2 | busselton
# Processing record 13 of set 2 | arraial do cabo
# City: arraial do cabo not found. Skipping...
# Processing record 14 of set 2 | saldanha
# Processing record 15 of set 2 | puerto ayora
# City: puerto ayora not found. Skipping...
# Processing record 16 of set 2 | hualmay
# Processing record 17 of set 2 | ballina
# Processing record 18 of set 2 | shingu
# Processing record 19 of set 2 | malatya
# Processing record 20 of set 2 | sibolga
# Processing record 21 of set 2 | lorengau
# Processing record 22 of set 2 | bambous virieux
# City: bambous virieux not found. Skipping...
# Processing record 23 of set 2 | ust-omchug
# Processing record 24 of set 2 | san quintin
# City: san quintin not found. Skipping...
# Processing record 25 of set 2 | phan rang
# City: phan rang not found. Skipping...
# Processing record 26 of set 2 | souillac
# Processing record 27 of set 2 | iqaluit
# Processing record 28 of set 2 | paamiut
# Processing record 29 of set 2 | luderitz
# Processing record 30 of set 2 | buarcos
# Processing record 31 of set 2 | upernavik
# Processing record 32 of set 2 | east london
# City: east london not found. Skipping...
# Processing record 33 of set 2 | guiyang
# Processing record 34 of set 2 | cherskiy
# Processing record 35 of set 2 | yellowknife
# Processing record 36 of set 2 | new norfolk
# City: new norfolk not found. Skipping...
# Processing record 37 of set 2 | long branch
# City: long branch not found. Skipping...
# Processing record 38 of set 2 | chicama
# Processing record 39 of set 2 | yulara
# Processing record 40 of set 2 | norfolk
# Processing record 41 of set 2 | port elizabeth
# City: port elizabeth not found. Skipping...
# Processing record 42 of set 2 | burica
# City: burica not found. Skipping...
# Processing record 43 of set 2 | bermeo
# Processing record 44 of set 2 | baruun-urt
# Processing record 45 of set 2 | tuatapere
# Processing record 46 of set 2 | namibe
# Processing record 47 of set 2 | dingle
# Processing record 48 of set 2 | carnarvon
# Processing record 49 of set 2 | atuona
# Processing record 50 of set 2 | pevek
# Processing record 1 of set 3 | mongo
# Processing record 2 of set 3 | caravelas
# Processing record 3 of set 3 | ilulissat
# Processing record 4 of set 3 | alexandria
# Processing record 5 of set 3 | yanam
# Processing record 6 of set 3 | nikolskoye
# Processing record 7 of set 3 | chapais
# Processing record 8 of set 3 | poum
# Processing record 9 of set 3 | bubaque
# Processing record 10 of set 3 | lolua
# City: lolua not found. Skipping...
# Processing record 11 of set 3 | jijiang
# Processing record 12 of set 3 | turinsk
# Processing record 13 of set 3 | ribeira grande
# City: ribeira grande not found. Skipping...
# Processing record 14 of set 3 | mys shmidta
# City: mys shmidta not found. Skipping...
# Processing record 15 of set 3 | atar
# Processing record 16 of set 3 | norman wells
# City: norman wells not found. Skipping...
# Processing record 17 of set 3 | gamba
# Processing record 18 of set 3 | tasiilaq
# Processing record 19 of set 3 | port hedland
# City: port hedland not found. Skipping...
# Processing record 20 of set 3 | lebu
# Processing record 21 of set 3 | gzhatsk
# City: gzhatsk not found. Skipping...
# Processing record 22 of set 3 | ojinaga
# Processing record 23 of set 3 | san juan
# City: san juan not found. Skipping...
# Processing record 24 of set 3 | cairns
# Processing record 25 of set 3 | inhambane
# Processing record 26 of set 3 | tiksi
# Processing record 27 of set 3 | aswan
# Processing record 28 of set 3 | tumannyy
# City: tumannyy not found. Skipping...
# Processing record 29 of set 3 | moree
# Processing record 30 of set 3 | eyl
# Processing record 31 of set 3 | baoshan
# Processing record 32 of set 3 | shelburne
# Processing record 33 of set 3 | brus laguna
# City: brus laguna not found. Skipping...
# Processing record 34 of set 3 | tadine
# Processing record 35 of set 3 | san patricio
# City: san patricio not found. Skipping...
# Processing record 36 of set 3 | taburi
# City: taburi not found. Skipping...
# Processing record 37 of set 3 | sentyabrskiy
# City: sentyabrskiy not found. Skipping...
# Processing record 38 of set 3 | cape town
# City: cape town not found. Skipping...
# Processing record 39 of set 3 | minuri
# Processing record 40 of set 3 | khonuu
# City: khonuu not found. Skipping...
# Processing record 41 of set 3 | cleethorpes
# Processing record 42 of set 3 | cidreira
# Processing record 43 of set 3 | hasaki
# Processing record 44 of set 3 | kalmunai
# Processing record 45 of set 3 | fortuna
# Processing record 46 of set 3 | tabou
# Processing record 47 of set 3 | aranda de duero
# City: aranda de duero not found. Skipping...
# Processing record 48 of set 3 | la rioja
# City: la rioja not found. Skipping...
# Processing record 49 of set 3 | mount isa
# City: mount isa not found. Skipping...
# Processing record 50 of set 3 | heze
# Processing record 1 of set 4 | laguna
# Processing record 2 of set 4 | albury
# Processing record 3 of set 4 | galgani
# City: galgani not found. Skipping...
# Processing record 4 of set 4 | sidi ali
# City: sidi ali not found. Skipping...
# Processing record 5 of set 4 | gari
# Processing record 6 of set 4 | katsuura
# Processing record 7 of set 4 | yarim
# Processing record 8 of set 4 | kahului
# Processing record 9 of set 4 | jamestown
# Processing record 10 of set 4 | mehriz
# Processing record 11 of set 4 | asyut
# Processing record 12 of set 4 | alofi
# Processing record 13 of set 4 | isangel
# Processing record 14 of set 4 | saint george
# City: saint george not found. Skipping...
# Processing record 15 of set 4 | ulaangom
# Processing record 16 of set 4 | coihaique
# Processing record 17 of set 4 | sao filipe
# City: sao filipe not found. Skipping...
# Processing record 18 of set 4 | muroto
# Processing record 19 of set 4 | geraldton
# Processing record 20 of set 4 | anklesvar
# City: anklesvar not found. Skipping...
# Processing record 21 of set 4 | antananarivo
# Processing record 22 of set 4 | bat khela
# City: bat khela not found. Skipping...
# Processing record 23 of set 4 | huarmey
# Processing record 24 of set 4 | katangli
# Processing record 25 of set 4 | yuzhno-yeniseyskiy
# City: yuzhno-yeniseyskiy not found. Skipping...
# Processing record 26 of set 4 | spearfish
# Processing record 27 of set 4 | longyearbyen
# Processing record 28 of set 4 | praia
# Processing record 29 of set 4 | kavieng
# Processing record 30 of set 4 | raahe
# Processing record 31 of set 4 | salama
# Processing record 32 of set 4 | ambilobe
# Processing record 33 of set 4 | chuy
# Processing record 34 of set 4 | bucerias
# Processing record 35 of set 4 | apatity
# Processing record 36 of set 4 | painesville
# Processing record 37 of set 4 | hamilton
# Processing record 38 of set 4 | magaria
# Processing record 39 of set 4 | terney
# Processing record 40 of set 4 | duz
# City: duz not found. Skipping...
# Processing record 41 of set 4 | port hardy
# City: port hardy not found. Skipping...
# Processing record 42 of set 4 | shieli
# Processing record 43 of set 4 | rach gia
# City: rach gia not found. Skipping...
# Processing record 44 of set 4 | chokurdakh
# Processing record 45 of set 4 | kyshtovka
# Processing record 46 of set 4 | arlit
# Processing record 47 of set 4 | acarau
# Processing record 48 of set 4 | ambagarh chauki
# City: ambagarh chauki not found. Skipping...
# Processing record 49 of set 4 | honiara
# Processing record 50 of set 4 | manaus
# Processing record 1 of set 5 | airai
# Processing record 2 of set 5 | portland
# Processing record 3 of set 5 | hervey bay
# City: hervey bay not found. Skipping...
# Processing record 4 of set 5 | marcona
# City: marcona not found. Skipping...
# Processing record 5 of set 5 | constitucion
# Processing record 6 of set 5 | saint-francois
# Processing record 7 of set 5 | vaitupu
# City: vaitupu not found. Skipping...
# Processing record 8 of set 5 | manjeshwar
# Processing record 9 of set 5 | bethel
# Processing record 10 of set 5 | alindao
# Processing record 11 of set 5 | rocha
# Processing record 12 of set 5 | alice springs
# City: alice springs not found. Skipping...
# Processing record 13 of set 5 | tura
# Processing record 14 of set 5 | kodiak
# Processing record 15 of set 5 | tete
# Processing record 16 of set 5 | goroka
# Processing record 17 of set 5 | berlevag
# Processing record 18 of set 5 | vila franca do campo
# City: vila franca do campo not found. Skipping...
# Processing record 19 of set 5 | okhotsk
# Processing record 20 of set 5 | pangody
# Processing record 21 of set 5 | hofn
# Processing record 22 of set 5 | sikonge
# Processing record 23 of set 5 | dikson
# Processing record 24 of set 5 | onega
# Processing record 25 of set 5 | amderma
# City: amderma not found. Skipping...
# Processing record 26 of set 5 | palabuhanratu
# City: palabuhanratu not found. Skipping...
# Processing record 27 of set 5 | aklavik
# Processing record 28 of set 5 | abilene
# Processing record 29 of set 5 | lata
# Processing record 30 of set 5 | balkhash
# Processing record 31 of set 5 | banda aceh
# City: banda aceh not found. Skipping...
# Processing record 32 of set 5 | state college
# City: state college not found. Skipping...
# Processing record 33 of set 5 | palm valley
# City: palm valley not found. Skipping...
# Processing record 34 of set 5 | muisne
# Processing record 35 of set 5 | saleaula
# City: saleaula not found. Skipping...
# Processing record 36 of set 5 | clyde river
# City: clyde river not found. Skipping...
# Processing record 37 of set 5 | kutum
# Processing record 38 of set 5 | college place
# City: college place not found. Skipping...
# Processing record 39 of set 5 | esperance
# Processing record 40 of set 5 | udachnyy
# Processing record 41 of set 5 | santa maria
# City: santa maria not found. Skipping...
# Processing record 42 of set 5 | cutervo
# Processing record 43 of set 5 | grindavik
# Processing record 44 of set 5 | ancud
# Processing record 45 of set 5 | faya
# Processing record 46 of set 5 | zyryanka
# Processing record 47 of set 5 | puerto escondido
# City: puerto escondido not found. Skipping...
# Processing record 48 of set 5 | palu
# Processing record 49 of set 5 | nivala
# Processing record 50 of set 5 | nalut
# Processing record 1 of set 6 | vung tau
# City: vung tau not found. Skipping...
# Processing record 2 of set 6 | riyadh
# Processing record 3 of set 6 | borogontsy
# Processing record 4 of set 6 | katherine
# Processing record 5 of set 6 | opuwo
# Processing record 6 of set 6 | angul
# Processing record 7 of set 6 | ife
# Processing record 8 of set 6 | oranjemund
# Processing record 9 of set 6 | armacao dos buzios
# City: armacao dos buzios not found. Skipping...
# Processing record 10 of set 6 | nanortalik
# Processing record 11 of set 6 | bengkulu
# Processing record 12 of set 6 | cabo san lucas
# City: cabo san lucas not found. Skipping...
# Processing record 13 of set 6 | iquique
# Processing record 14 of set 6 | jiayuguan
# Processing record 15 of set 6 | chauk
# Processing record 16 of set 6 | mwene-ditu
# Processing record 17 of set 6 | martapura
# Processing record 18 of set 6 | tsihombe
# City: tsihombe not found. Skipping...
# Processing record 19 of set 6 | traralgon
# Processing record 20 of set 6 | sao raimundo das mangabeiras
# City: sao raimundo das mangabeiras not found. Skipping...
# Processing record 21 of set 6 | ixtapa
# Processing record 22 of set 6 | anito
# Processing record 23 of set 6 | moron
# Processing record 24 of set 6 | vardo
# Processing record 25 of set 6 | gobabis
# Processing record 26 of set 6 | hibbing
# Processing record 27 of set 6 | martaban
# Processing record 28 of set 6 | saint-joseph
# Processing record 29 of set 6 | alugan
# Processing record 30 of set 6 | menongue
# Processing record 31 of set 6 | bathsheba
# Processing record 32 of set 6 | waipawa
# Processing record 33 of set 6 | attawapiskat
# City: attawapiskat not found. Skipping...
# Processing record 34 of set 6 | dauphin
# Processing record 35 of set 6 | poli
# Processing record 36 of set 6 | thinadhoo
# Processing record 37 of set 6 | comodoro rivadavia
# City: comodoro rivadavia not found. Skipping...
# Processing record 38 of set 6 | kailua
# Processing record 39 of set 6 | tilichiki
# Processing record 40 of set 6 | champerico
# Processing record 41 of set 6 | georgetown
# Processing record 42 of set 6 | hay river
# City: hay river not found. Skipping...
# Processing record 43 of set 6 | ust-maya
# Processing record 44 of set 6 | zaragoza
# Processing record 45 of set 6 | deputatskiy
# Processing record 46 of set 6 | letlhakane
# Processing record 47 of set 6 | kaitangata
# Processing record 48 of set 6 | altay
# Processing record 49 of set 6 | rolim de moura
# City: rolim de moura not found. Skipping...
# Processing record 50 of set 6 | ostrovskoye
# Processing record 1 of set 7 | salinopolis
# Processing record 2 of set 7 | daru
# Processing record 3 of set 7 | puerto lopez
# City: puerto lopez not found. Skipping...
# Processing record 4 of set 7 | ternate
# Processing record 5 of set 7 | vao
# Processing record 6 of set 7 | avera
# Processing record 7 of set 7 | richards bay
# City: richards bay not found. Skipping...
# Processing record 8 of set 7 | khash
# Processing record 9 of set 7 | hobyo
# Processing record 10 of set 7 | mehamn
# Processing record 11 of set 7 | hlobyne
# Processing record 12 of set 7 | na klang
# City: na klang not found. Skipping...
# Processing record 13 of set 7 | scottsbluff
# Processing record 14 of set 7 | flin flon
# City: flin flon not found. Skipping...
# Processing record 15 of set 7 | sungaipenuh
# Processing record 16 of set 7 | barrow
# Processing record 17 of set 7 | talnakh
# Processing record 18 of set 7 | arica
# Processing record 19 of set 7 | ankara
# Processing record 20 of set 7 | middlebury
# Processing record 21 of set 7 | balad
# Processing record 22 of set 7 | yumen
# Processing record 23 of set 7 | khasan
# Processing record 24 of set 7 | ozgon
# City: ozgon not found. Skipping...
# Processing record 25 of set 7 | nizhneyansk
# City: nizhneyansk not found. Skipping...
# Processing record 26 of set 7 | staryy nadym
# City: staryy nadym not found. Skipping...
# Processing record 27 of set 7 | igarka
# Processing record 28 of set 7 | pervomayskiy
# Processing record 29 of set 7 | byron bay
# City: byron bay not found. Skipping...
# Processing record 30 of set 7 | ordynskoye
# Processing record 31 of set 7 | hermanus
# Processing record 32 of set 7 | fairbanks
# Processing record 33 of set 7 | salalah
# Processing record 34 of set 7 | severo-kurilsk
# Processing record 35 of set 7 | cuncolim
# Processing record 36 of set 7 | san mateo ixtatan
# City: san mateo ixtatan not found. Skipping...
# Processing record 37 of set 7 | tunghsiao
# City: tunghsiao not found. Skipping...
# Processing record 38 of set 7 | lianzhou
# Processing record 39 of set 7 | chabahar
# Processing record 40 of set 7 | cayenne
# Processing record 41 of set 7 | sisimiut
# Processing record 42 of set 7 | prince rupert
# City: prince rupert not found. Skipping...
# Processing record 43 of set 7 | saint johnsbury
# City: saint johnsbury not found. Skipping...
# Processing record 44 of set 7 | saskylakh
# Processing record 45 of set 7 | aravete
# Processing record 46 of set 7 | dzilam gonzalez
# City: dzilam gonzalez not found. Skipping...
# Processing record 47 of set 7 | yar-sale
# Processing record 48 of set 7 | tigre
# Processing record 49 of set 7 | bulancak
# Processing record 50 of set 7 | half moon bay
# City: half moon bay not found. Skipping...
# Processing record 1 of set 8 | khilok
# Processing record 2 of set 8 | irbeyskoye
# Processing record 3 of set 8 | kruisfontein
# Processing record 4 of set 8 | olafsvik
# Processing record 5 of set 8 | wulanhaote
# City: wulanhaote not found. Skipping...
# Processing record 6 of set 8 | skibbereen
# Processing record 7 of set 8 | parkes
# Processing record 8 of set 8 | meulaboh
# Processing record 9 of set 8 | ventspils
# Processing record 10 of set 8 | mackay
# Processing record 11 of set 8 | mocambique
# City: mocambique not found. Skipping...
# Processing record 12 of set 8 | hammerfest
# Processing record 13 of set 8 | ranong
# Processing record 14 of set 8 | amberley
# Processing record 15 of set 8 | sao joao da barra
# City: sao joao da barra not found. Skipping...
# Processing record 16 of set 8 | newport
# Processing record 17 of set 8 | torbay
# Processing record 18 of set 8 | mezen
# Processing record 19 of set 8 | namanga
# Processing record 20 of set 8 | privokzalnyy
# City: privokzalnyy not found. Skipping...
# Processing record 21 of set 8 | penzance
# Processing record 22 of set 8 | acapulco
# Processing record 23 of set 8 | chengde
# Processing record 24 of set 8 | zabol
# Processing record 25 of set 8 | veraval
# Processing record 26 of set 8 | san andres
# City: san andres not found. Skipping...
# Processing record 27 of set 8 | joao pinheiro
# City: joao pinheiro not found. Skipping...
# Processing record 28 of set 8 | guiratinga
# Processing record 29 of set 8 | kununurra
# Processing record 30 of set 8 | louisbourg
# City: louisbourg not found. Skipping...
# Processing record 31 of set 8 | hami
# Processing record 32 of set 8 | tanout
# Processing record 33 of set 8 | ostrovnoy
# Processing record 34 of set 8 | belyy yar
# City: belyy yar not found. Skipping...
# Processing record 35 of set 8 | auchi
# Processing record 36 of set 8 | gbarnga
# Processing record 37 of set 8 | pauini
# Processing record 38 of set 8 | leningradskiy
# Processing record 39 of set 8 | lompoc
# Processing record 40 of set 8 | erzin
# Processing record 41 of set 8 | asmar
# Processing record 42 of set 8 | corumba
# Processing record 43 of set 8 | shiraz
# Processing record 44 of set 8 | setermoen
# Processing record 45 of set 8 | msanga
# Processing record 46 of set 8 | bokspits
# City: bokspits not found. Skipping...
# Processing record 47 of set 8 | dubovskoye
# Processing record 48 of set 8 | erenhot
# Processing record 49 of set 8 | labuhan
# Processing record 50 of set 8 | houma
# Processing record 1 of set 9 | omsukchan
# Processing record 2 of set 9 | benjamin constant
# City: benjamin constant not found. Skipping...
# Processing record 3 of set 9 | sorong
# Processing record 4 of set 9 | maromitsa
# Processing record 5 of set 9 | ponta delgada
# City: ponta delgada not found. Skipping...
# Processing record 6 of set 9 | hounde
# Processing record 7 of set 9 | louviers
# Processing record 8 of set 9 | mao
# Processing record 9 of set 9 | scarborough
# Processing record 10 of set 9 | dafeng
# Processing record 11 of set 9 | karratha
# Processing record 12 of set 9 | qaqortoq
# Processing record 13 of set 9 | benalla
# Processing record 14 of set 9 | ahipara
# Processing record 15 of set 9 | port macquarie
# City: port macquarie not found. Skipping...
# Processing record 16 of set 9 | beyneu
# Processing record 17 of set 9 | bolobo
# Processing record 18 of set 9 | aksu
# Processing record 19 of set 9 | mogadishu
# Processing record 20 of set 9 | kungurtug
# Processing record 21 of set 9 | port shepstone
# City: port shepstone not found. Skipping...
# Processing record 22 of set 9 | petropavlovsk-kamchatskiy
# Processing record 23 of set 9 | antofagasta
# Processing record 24 of set 9 | sangar
# Processing record 25 of set 9 | lasa
# Processing record 26 of set 9 | umea
# Processing record 27 of set 9 | sechura
# Processing record 28 of set 9 | marystown
# Processing record 29 of set 9 | tautira
# Processing record 30 of set 9 | tuy hoa
# City: tuy hoa not found. Skipping...
# Processing record 31 of set 9 | zile
# Processing record 32 of set 9 | seoul
# Processing record 33 of set 9 | duluth
# Processing record 34 of set 9 | camana
# Processing record 35 of set 9 | mount gambier
# City: mount gambier not found. Skipping...
# Processing record 36 of set 9 | sur
# Processing record 37 of set 9 | sambava
# Processing record 38 of set 9 | darayya
# Processing record 39 of set 9 | uspenka
# Processing record 40 of set 9 | bismarck
# Processing record 41 of set 9 | san cristobal
# City: san cristobal not found. Skipping...
# Processing record 42 of set 9 | haines junction
# City: haines junction not found. Skipping...
# Processing record 43 of set 9 | conroe
# Processing record 44 of set 9 | praia da vitoria
# City: praia da vitoria not found. Skipping...
# Processing record 45 of set 9 | treinta y tres
# City: treinta y tres not found. Skipping...
# Processing record 46 of set 9 | bodaybo
# Processing record 47 of set 9 | ust-tsilma
# Processing record 48 of set 9 | chagoda
# Processing record 49 of set 9 | auki
# Processing record 50 of set 9 | blonduos
# City: blonduos not found. Skipping...
# Processing record 1 of set 10 | tromso
# Processing record 2 of set 10 | fairview
# Processing record 3 of set 10 | la tuque
# City: la tuque not found. Skipping...
# Processing record 4 of set 10 | buzuluk
# Processing record 5 of set 10 | mogwase
# Processing record 6 of set 10 | bay city
# City: bay city not found. Skipping...
# Processing record 7 of set 10 | umzimvubu
# City: umzimvubu not found. Skipping...
# Processing record 8 of set 10 | kathu
# Processing record 9 of set 10 | ponta do sol
# City: ponta do sol not found. Skipping...
# Processing record 10 of set 10 | panguna
# Processing record 11 of set 10 | azimur
# City: azimur not found. Skipping...
# Processing record 12 of set 10 | grand river south east
# City: grand river south east not found. Skipping...
# Processing record 13 of set 10 | nemuro
# Processing record 14 of set 10 | abu dhabi
# City: abu dhabi not found. Skipping...
# Processing record 15 of set 10 | pathein
# Processing record 16 of set 10 | urucui
# Processing record 17 of set 10 | wanaka
# Processing record 18 of set 10 | nome
# Processing record 19 of set 10 | novobirilyussy
# Processing record 20 of set 10 | santa rosa
# City: santa rosa not found. Skipping...
# Processing record 21 of set 10 | komsomolets
# Processing record 22 of set 10 | sayyan
# Processing record 23 of set 10 | el sauzal
# City: el sauzal not found. Skipping...
# Processing record 24 of set 10 | arman
# Processing record 25 of set 10 | san policarpo
# City: san policarpo not found. Skipping...
# Processing record 26 of set 10 | tashigang
# Processing record 27 of set 10 | sekoma
# Processing record 28 of set 10 | suleja
# Processing record 29 of set 10 | irbil
# Processing record 30 of set 10 | manlleu
# Processing record 31 of set 10 | mareeba
# Processing record 32 of set 10 | samusu
# City: samusu not found. Skipping...
# Processing record 33 of set 10 | indian head
# City: indian head not found. Skipping...
# Processing record 34 of set 10 | atambua
# Processing record 35 of set 10 | tual
# Processing record 36 of set 10 | colares
# Processing record 37 of set 10 | huangchuan
# Processing record 38 of set 10 | safwah
# City: safwah not found. Skipping...
# Processing record 39 of set 10 | ilinskiy
# Processing record 40 of set 10 | tezu
# Processing record 41 of set 10 | gazanjyk
# Processing record 42 of set 10 | marsassoum
# Processing record 43 of set 10 | tempio pausania
# City: tempio pausania not found. Skipping...
# Processing record 44 of set 10 | moorhead
# Processing record 45 of set 10 | vrangel
# Processing record 46 of set 10 | zhangjiakou
# Processing record 47 of set 10 | vieste
# Processing record 48 of set 10 | morro bay
# City: morro bay not found. Skipping...
# Processing record 49 of set 10 | brenham
# Processing record 50 of set 10 | campbell river
# City: campbell river not found. Skipping...
# Processing record 1 of set 11 | korla
# Processing record 2 of set 11 | tabas
# Processing record 3 of set 11 | monrovia
# Processing record 4 of set 11 | srivardhan
# Processing record 5 of set 11 | makakilo city
# City: makakilo city not found. Skipping...
# Processing record 6 of set 11 | port lincoln
# City: port lincoln not found. Skipping...
# Processing record 7 of set 11 | progreso
# Processing record 8 of set 11 | northam
# Processing record 9 of set 11 | skagastrond
# City: skagastrond not found. Skipping...
# Processing record 10 of set 11 | bac lieu
# City: bac lieu not found. Skipping...
# Processing record 11 of set 11 | fuxin
# Processing record 12 of set 11 | luocheng
# Processing record 13 of set 11 | gouyave
# Processing record 14 of set 11 | anzhero-sudzhensk
# Processing record 15 of set 11 | necochea
# Processing record 16 of set 11 | baculin
# Processing record 17 of set 11 | rong kwang
# City: rong kwang not found. Skipping...
# Processing record 18 of set 11 | aripuana
# Processing record 19 of set 11 | mogochin
# City: mogochin not found. Skipping...
# Processing record 20 of set 11 | ucluelet
# Processing record 21 of set 11 | bandrele
# Processing record 22 of set 11 | saint anthony
# City: saint anthony not found. Skipping...
# Processing record 23 of set 11 | ugoofaaru
# Processing record 24 of set 11 | krasnoselkup
# Processing record 25 of set 11 | along
# Processing record 26 of set 11 | araouane
# Processing record 27 of set 11 | asau
# Processing record 28 of set 11 | ulladulla
# Processing record 29 of set 11 | at-bashi
# Processing record 30 of set 11 | skalistyy
# City: skalistyy not found. Skipping...
# Processing record 31 of set 11 | benguela
# Processing record 32 of set 11 | sao felix do xingu
# City: sao felix do xingu not found. Skipping...
# Processing record 33 of set 11 | mitsamiouli
# Processing record 34 of set 11 | rio grande
# City: rio grande not found. Skipping...
# Processing record 35 of set 11 | samarai
# Processing record 36 of set 11 | rio gallegos
# City: rio gallegos not found. Skipping...
# Processing record 37 of set 11 | kemalpasa
# Processing record 38 of set 11 | taoudenni
# Processing record 39 of set 11 | bay roberts
# City: bay roberts not found. Skipping...
# Processing record 40 of set 11 | santa cruz
# City: santa cruz not found. Skipping...
# Processing record 41 of set 11 | bogashevo
# Processing record 42 of set 11 | baiyin
# Processing record 43 of set 11 | kashi
# Processing record 44 of set 11 | flinders
# Processing record 45 of set 11 | verkhoyansk
# Processing record 46 of set 11 | pitimbu
# Processing record 47 of set 11 | sudak
# Processing record 48 of set 11 | chancay
# Processing record 49 of set 11 | bud
# Processing record 50 of set 11 | coquimbo
# Processing record 1 of set 12 | gubkinskiy
# Processing record 2 of set 12 | cumaribo
# City: cumaribo not found. Skipping...
# Processing record 3 of set 12 | makushino
# Processing record 4 of set 12 | ryotsu
# Processing record 5 of set 12 | san matias
# City: san matias not found. Skipping...
# Processing record 6 of set 12 | kadoshkino
# Processing record 7 of set 12 | grand gaube
# City: grand gaube not found. Skipping...
# Processing record 8 of set 12 | amga
# Processing record 9 of set 12 | sovetskiy
# Processing record 10 of set 12 | the valley
# City: the valley not found. Skipping...
# Processing record 11 of set 12 | presidente medici
# City: presidente medici not found. Skipping...
# Processing record 12 of set 12 | kargil
# Processing record 13 of set 12 | koraput
# Processing record 14 of set 12 | humaita
# Processing record 15 of set 12 | naze
# Processing record 16 of set 12 | mayumba
# Processing record 17 of set 12 | puerto guzman
# City: puerto guzman not found. Skipping...
# Processing record 18 of set 12 | baishishan
# Processing record 19 of set 12 | north platte
# City: north platte not found. Skipping...
# Processing record 20 of set 12 | dunedin
# Processing record 21 of set 12 | powell river
# City: powell river not found. Skipping...
# Processing record 22 of set 12 | pechora
# Processing record 23 of set 12 | thabazimbi
# Processing record 24 of set 12 | bintulu
# Processing record 25 of set 12 | ust-kamchatsk
# City: ust-kamchatsk not found. Skipping...
# Processing record 26 of set 12 | panaba
# Processing record 27 of set 12 | vasilsursk
# Processing record 28 of set 12 | batemans bay
# City: batemans bay not found. Skipping...
# Processing record 29 of set 12 | sistranda
# Processing record 30 of set 12 | shimoda
# Processing record 31 of set 12 | upata
# Processing record 32 of set 12 | sultanpur
# Processing record 33 of set 12 | nouakchott
# Processing record 34 of set 12 | taltal
# Processing record 35 of set 12 | laramie
# Processing record 36 of set 12 | lagoa
# Processing record 37 of set 12 | kirakira
# Processing record 38 of set 12 | egvekinot
# Processing record 39 of set 12 | surt
# Processing record 40 of set 12 | skegness
# Processing record 41 of set 12 | disna
# Processing record 42 of set 12 | westport
# Processing record 43 of set 12 | ilo
# Processing record 44 of set 12 | lalmohan
# Processing record 45 of set 12 | mecca
# Processing record 46 of set 12 | kuala pilah
# City: kuala pilah not found. Skipping...
# Processing record 47 of set 12 | teknaf
# Processing record 48 of set 12 | zatoka
# Processing record 49 of set 12 | mana
# Processing record 50 of set 12 | zarubino
# Processing record 1 of set 13 | bairiki
# Processing record 2 of set 13 | caninde
# Processing record 3 of set 13 | pimentel
# Processing record 4 of set 13 | santa fe
# City: santa fe not found. Skipping...
# Processing record 5 of set 13 | viedma
# Processing record 6 of set 13 | mazagao
# Processing record 7 of set 13 | riverton
# Processing record 8 of set 13 | sultepec
# Processing record 9 of set 13 | cockburn town
# City: cockburn town not found. Skipping...
# Processing record 10 of set 13 | baracoa
# Processing record 11 of set 13 | tabasalu
# Processing record 12 of set 13 | bolungarvik
# City: bolungarvik not found. Skipping...
# Processing record 13 of set 13 | port hawkesbury
# City: port hawkesbury not found. Skipping...
# Processing record 14 of set 13 | tessalit
# Processing record 15 of set 13 | imbituba
# Processing record 16 of set 13 | touros
# Processing record 17 of set 13 | bereda
# Processing record 18 of set 13 | barysh
# Processing record 19 of set 13 | calama
# Processing record 20 of set 13 | bertoua
# Processing record 21 of set 13 | fukue
# Processing record 22 of set 13 | lazarev
# Processing record 23 of set 13 | khandyga
# Processing record 24 of set 13 | haibara
# Processing record 25 of set 13 | biltine
# Processing record 26 of set 13 | ilovlya
# Processing record 27 of set 13 | methoni
# Processing record 28 of set 13 | batagay-alyta
# Processing record 29 of set 13 | quatre cocos
# City: quatre cocos not found. Skipping...
# Processing record 30 of set 13 | olinda
# Processing record 31 of set 13 | port blair
# City: port blair not found. Skipping...
# Processing record 32 of set 13 | lazdijai
# Processing record 33 of set 13 | sorvag
# City: sorvag not found. Skipping...
# Processing record 34 of set 13 | paradise
# Processing record 35 of set 13 | wanning
# Processing record 36 of set 13 | buraydah
# Processing record 37 of set 13 | omboue
# Processing record 38 of set 13 | filingue
# Processing record 39 of set 13 | lancaster
# Processing record 40 of set 13 | bergen
# Processing record 41 of set 13 | hillsboro
# Processing record 42 of set 13 | husavik
# Processing record 43 of set 13 | biak
# Processing record 44 of set 13 | harare
# Processing record 45 of set 13 | bambanglipuro
# Processing record 46 of set 13 | rameswaram
# Processing record 47 of set 13 | banepa
# Processing record 48 of set 13 | bilma
# Processing record 49 of set 13 | bumba
# Processing record 50 of set 13 | paea
# Processing record 1 of set 14 | beloha
# Processing record 2 of set 14 | quesnel
# Processing record 3 of set 14 | hirara
# Processing record 4 of set 14 | yeniseysk
# Processing record 5 of set 14 | santiago de cao
# City: santiago de cao not found. Skipping...
# Processing record 6 of set 14 | lashio
# Processing record 7 of set 14 | dzerzhinskoye
# Processing record 8 of set 14 | soe
# Processing record 9 of set 14 | sibut
# Processing record 10 of set 14 | panzhihua
# Processing record 11 of set 14 | shangzhi
# Processing record 12 of set 14 | diamantino
# Processing record 13 of set 14 | antsohihy
# Processing record 14 of set 14 | eureka
# Processing record 15 of set 14 | walvis bay
# City: walvis bay not found. Skipping...
# Processing record 16 of set 14 | ifo
# Processing record 17 of set 14 | raudeberg
# Processing record 18 of set 14 | halalo
# City: halalo not found. Skipping...
# Processing record 19 of set 14 | sug-aksy
# City: sug-aksy not found. Skipping...
# Processing record 20 of set 14 | nevsehir
# Processing record 21 of set 14 | changji
# Processing record 22 of set 14 | pacific grove
# City: pacific grove not found. Skipping...
# Processing record 23 of set 14 | ngunguru
# Processing record 24 of set 14 | ozuluama
# Processing record 25 of set 14 | sumbawa
# City: sumbawa not found. Skipping...
# Processing record 26 of set 14 | toliary
# City: toliary not found. Skipping...
# Processing record 27 of set 14 | altamira
# Processing record 28 of set 14 | nantucket
# Processing record 29 of set 14 | te anau
# City: te anau not found. Skipping...
# Processing record 30 of set 14 | matara
# Processing record 31 of set 14 | tarija
# Processing record 32 of set 14 | talara
# Processing record 33 of set 14 | cap malheureux
# City: cap malheureux not found. Skipping...
# Processing record 34 of set 14 | braedstrup
# Processing record 35 of set 14 | wilmington
# Processing record 36 of set 14 | jaisalmer
# Processing record 37 of set 14 | nuzvid
# Processing record 38 of set 14 | lodja
# Processing record 39 of set 14 | kurmanayevka
# Processing record 40 of set 14 | port-gentil
# Processing record 41 of set 14 | jiddah
# City: jiddah not found. Skipping...
# Processing record 42 of set 14 | palora
# Processing record 43 of set 14 | mutare
# Processing record 44 of set 14 | kaili
# Processing record 45 of set 14 | karakol
# Processing record 46 of set 14 | murgab
# Processing record 47 of set 14 | vodnyy
# Processing record 48 of set 14 | ismailia
# Processing record 49 of set 14 | viligili
# City: viligili not found. Skipping...
# Processing record 50 of set 14 | eskisehir
# Processing record 1 of set 15 | ahuimanu
# Processing record 2 of set 15 | kloulklubed
# Processing record 3 of set 15 | guerrero negro
# City: guerrero negro not found. Skipping...
# Processing record 4 of set 15 | solovetskiy
# City: solovetskiy not found. Skipping...
# Processing record 5 of set 15 | coahuayana
# Processing record 6 of set 15 | kendal
# Processing record 7 of set 15 | miri
# Processing record 8 of set 15 | pimenta bueno
# City: pimenta bueno not found. Skipping...
# Processing record 9 of set 15 | hovd
# Processing record 10 of set 15 | ouegoa
# Processing record 11 of set 15 | havre-saint-pierre
# Processing record 12 of set 15 | tarko-sale
# Processing record 13 of set 15 | jiuquan
# Processing record 14 of set 15 | cartagena
# Processing record 15 of set 15 | port pirie
# City: port pirie not found. Skipping...
# Processing record 16 of set 15 | cumra
# Processing record 17 of set 15 | ziro
# Processing record 18 of set 15 | tuggurt
# City: tuggurt not found. Skipping...
# Processing record 19 of set 15 | bilibino
# Processing record 20 of set 15 | rawannawi
# City: rawannawi not found. Skipping...
# Processing record 21 of set 15 | peniche
# Processing record 22 of set 15 | nishihara
# Processing record 23 of set 15 | north bend
# City: north bend not found. Skipping...
# Processing record 24 of set 15 | turan
# Processing record 25 of set 15 | svetlogorsk
# Processing record 26 of set 15 | buala
# Processing record 27 of set 15 | strezhevoy
# Processing record 28 of set 15 | phek
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert data into DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Hohr-Grenzhausen      DE  50.4333    7.6667     68.04        92
# 1            Narsaq      GL  60.9167  -46.0500     59.22        53
# 2         Mahebourg      MU -20.4081   57.7000     70.09        64
# 3         Hithadhoo      MV  -0.6000   73.0833     80.60        75
# 4              Hilo      US  19.7297 -155.0900     82.80        85
# 5           Rikitea      PF -23.1203 -134.9692     70.65        67
# 6            Trairi      BR  -3.2778  -39.2689     80.28        68
# 7            Broome      US  42.2506  -75.8330     85.69        64
# 8        Butaritari      KI   3.0707  172.7902     82.08        74
# 9       Provideniya      RU  64.3833 -173.3000     46.51       100
#
#    Cloudiness  Wind Speed Current Description
# 0          13        3.65          few clouds
# 1          42        4.36    scattered clouds
# 2          20       11.50          few clouds
# 3          87        4.00          light rain
# 4          90        4.61          light rain
# 5          38        6.42    scattered clouds
# 6          17       12.71          few clouds
# 7          40        3.00    scattered clouds
# 8          92       11.12       moderate rain
# 9          90        6.71                 fog

# %%
# output DataFrame to csv
output_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_file, index_label="City ID")
